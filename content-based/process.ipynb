# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt
from sklearn.utils import shuffle
from sortedcontainers import SortedList
from sklearn.model_selection import train_test_split
import math

# %%
df = pd.read_csv('../dataset/movie_additional.csv')
df = shuffle(df)

# %%
df.head(10)
# Out:
#              id                         name  \
# 447   tt1630029     Avatar: The Way of Water
# 247  tt10332508                       Primal
# 200   tt8503618                     Hamilton
# 125   tt1513168         Through the Wormhole
# 377   tt0126029                        Shrek
# 314   tt3428912                 Happy Valley
# 189   tt0032455                     Fantasia
# 359   tt0036868  The Best Years of Our Lives
# 267   tt1518542        Sarabhai V/S Sarabhai
# 478   tt0808417                   Persepolis
#
#                                                 poster  \
# 447  https://m.media-amazon.com/images/M/MV5BYjhiNj...
# 247  https://m.media-amazon.com/images/M/MV5BYjk3Y2...
# 200  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 125  https://m.media-amazon.com/images/M/MV5BMDhkMT...
# 377  https://m.media-amazon.com/images/M/MV5BOGZhM2...
# 314  https://m.media-amazon.com/images/M/MV5BNTBmYT...
# 189  https://m.media-amazon.com/images/M/MV5BMjAxMT...
# 359  https://m.media-amazon.com/images/M/MV5BY2RmNT...
# 267  https://m.media-amazon.com/images/M/MV5BNjYxNz...
# 478  https://m.media-amazon.com/images/M/MV5BMGRkZT...
#
#                                              directors  \
# 447                                      James Cameron
# 247                                 Genndy Tartakovsky
# 200                                        Thomas Kail
# 125                                                  |
# 377                        Andrew Adamson|Vicky Jenson
# 314                                   Sally Wainwright
# 189  Directors|James Algar|Samuel Armstrong|Ford Be...
# 359                                      William Wyler
# 267                                                  |
# 478                  Vincent Paronnaud|Marjane Satrapi
#
#                                              writers  \
# 447  Writers|James Cameron|Rick Jaffa|Amanda Silver|
# 247                                                |
# 200                   Lin-Manuel Miranda|Ron Chernow
# 125                                                |
# 377  Writers|William Steig|Ted Elliott|Terry Rossio|
# 314                                                |
# 189         Writers|Joe Grant|Dick Huemer|Lee Blair|
# 359              Robert E. Sherwood|MacKinlay Kantor
# 267                                                |
# 478                Marjane Satrapi|Vincent Paronnaud
#
#                          genres  \
# 447    Action|Adventure|Fantasy
# 247  Animation|Action|Adventure
# 200     Biography|Drama|History
# 125                 Documentary
# 377  Animation|Adventure|Comedy
# 314        Crime|Drama|Thriller
# 189    Animation|Family|Fantasy
# 359           Drama|Romance|War
# 267                      Comedy
# 478   Animation|Biography|Drama
#
#                                                 actors  releaseYear     limit  \
# 447  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...         2022     PG-13
# 247  Aaron LaPlante|Latitia Edo|Fred Tatasciore|Ima...         2019     TV-MA
# 200  Lin-Manuel Miranda|Phillipa Soo|Leslie Odom Jr...         2020     PG-13
# 125  Morgan Freeman|Sean Carroll|Michio Kaku|Kip Th...     20102017     TV-PG
# 377  Mike Myers|Eddie Murphy|Cameron Diaz|John Lith...         2001        PG
# 314  Sarah Lancashire|Siobhan Finneran|James Norton...     20142023     TV-MA
# 189  Leopold Stokowski|Deems Taylor|The Philadelphi...         1940         G
# 359  Myrna Loy|Dana Andrews|Fredric March|Teresa Wr...         1946  Approved
# 267  Satish Shah|Ratna Pathak Shah|Sumeet Raghavan|...     20042017     TV-PG
# 478  Chiara Mastroianni|Catherine Deneuve|Gena Rowl...         2007     PG-13
#
#     duration language          origin
# 447   3h 12m  English   United States
# 247      22m  English   United States
# 200   2h 40m  English   United States
# 125       1h  English   United States
# 377   1h 30m  English   United States
# 314      58m  English  United Kingdom
# 189    2h 4m  English   United States
# 359   2h 50m  English   United States
# 267      30m    Hindi           India
# 478   1h 36m   French          France

# %%
for i in range(0, len(df)):
    time = df['duration'][i]
    try:
        df['duration'][i] = int(time[:time.index('h')]) * 60
    except:
        df['duration'][i] = int(time[:time.index('m')])

    if len(time.split(' ')) > 1:
        df['duration'][i] += int(time.split(' ')[1][:time.split(' ')[1].index('m')])
# Out:
# C:\Users\dekub\AppData\Local\Temp\ipykernel_30064\631852105.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration'][i] = int(time[:time.index('h')]) * 60
# C:\Users\dekub\AppData\Local\Temp\ipykernel_30064\631852105.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration'][i] += int(time.split(' ')[1][:time.split(' ')[1].index('m')])
# C:\Users\dekub\AppData\Local\Temp\ipykernel_30064\631852105.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['duration'][i] = int(time[:time.index('m')])

# %%
df.head(5)
# Out:
#              id                      name  \
# 447   tt1630029  Avatar: The Way of Water
# 247  tt10332508                    Primal
# 200   tt8503618                  Hamilton
# 125   tt1513168      Through the Wormhole
# 377   tt0126029                     Shrek
#
#                                                 poster  \
# 447  https://m.media-amazon.com/images/M/MV5BYjhiNj...
# 247  https://m.media-amazon.com/images/M/MV5BYjk3Y2...
# 200  https://m.media-amazon.com/images/M/MV5BNjViNW...
# 125  https://m.media-amazon.com/images/M/MV5BMDhkMT...
# 377  https://m.media-amazon.com/images/M/MV5BOGZhM2...
#
#                        directors  \
# 447                James Cameron
# 247           Genndy Tartakovsky
# 200                  Thomas Kail
# 125                            |
# 377  Andrew Adamson|Vicky Jenson
#
#                                              writers  \
# 447  Writers|James Cameron|Rick Jaffa|Amanda Silver|
# 247                                                |
# 200                   Lin-Manuel Miranda|Ron Chernow
# 125                                                |
# 377  Writers|William Steig|Ted Elliott|Terry Rossio|
#
#                          genres  \
# 447    Action|Adventure|Fantasy
# 247  Animation|Action|Adventure
# 200     Biography|Drama|History
# 125                 Documentary
# 377  Animation|Adventure|Comedy
#
#                                                 actors  releaseYear  limit  \
# 447  Sam Worthington|Zoe Saldana|Sigourney Weaver|S...         2022  PG-13
# 247  Aaron LaPlante|Latitia Edo|Fred Tatasciore|Ima...         2019  TV-MA
# 200  Lin-Manuel Miranda|Phillipa Soo|Leslie Odom Jr...         2020  PG-13
# 125  Morgan Freeman|Sean Carroll|Michio Kaku|Kip Th...     20102017  TV-PG
# 377  Mike Myers|Eddie Murphy|Cameron Diaz|John Lith...         2001     PG
#
#     duration language         origin
# 447      192  English  United States
# 247       22  English  United States
# 200      160  English  United States
# 125       60  English  United States
# 377       90  English  United States

# %%
movies = {}
for row in df.values:
    id, name, poster, directors, writers, genres, actors, releaseYear, limit, duration, language, origin = row
    movies[id] = {
        'name': name,
        'poster': poster,
        'directors': directors,
        'genres': genres,
        'actors': actors,
        'releaseYear': releaseYear,
        'limit': limit,
        'duration': duration,
        'writers': writers,
        'language': language,
        'origin': origin
    }

# %%
def get_sim_director(movie_id_i, movie_id_j):
    director_i = set(movies[movie_id_i]['directors'])
    director_j = set(movies[movie_id_j]['directors'])

    return 0.125 * (len(director_i.intersection(director_j)) / len(director_i.union(director_j)))

def get_sim_writer(movie_id_i, movie_id_j):
    writer_i = set(movies[movie_id_i]['writers'])
    writer_j = set(movies[movie_id_j]['writers'])

    return 0.125 * (len(writer_i.intersection(writer_j)) / len(writer_i.union(writer_j)))

def get_sim_actor(movie_id_i, movie_id_j):
    actor_i = set(movies[movie_id_i]['actors'])
    actor_j = set(movies[movie_id_j]['actors'])

    return 0.125 * (len(actor_i.intersection(actor_j)) / len(actor_i.union(actor_j)))

def get_sim_releaseYear(movie_id_i, movie_id_j):
    releaseYear_i = int(movies[movie_id_i]['releaseYear'])
    releaseYear_j = int(movies[movie_id_j]['releaseYear'])

    diff = abs(releaseYear_i - releaseYear_j)
    if diff < 3:
        return 0.05
    elif diff < 5:
        return 0.05 * 0.8
    elif diff < 10:
        return 0.05 * 0.5
    elif diff < 20:
        return 0.05 * 0.3
    return 0

def get_sim_genres(movie_id_i, movie_id_j):
    genres_i = set(movies[movie_id_i]['genres'])
    genres_j = set(movies[movie_id_j]['genres'])

    return 0.35 * (len(genres_i.intersection(genres_j)) / len(genres_i.union(genres_j)))

def get_sim_limit(movie_id_i, movie_id_j):
    limit_i = movies[movie_id_i]['limit']
    limit_j = movies[movie_id_j]['limit']
    if limit_i == limit_j:
        return 0.025
    return 0

def get_sim_duration(movie_id_i, movie_id_j):
    duration_i = float(movies[movie_id_i]['duration'])
    duration_j = float(movies[movie_id_j]['duration'])

    diff = abs(duration_i - duration_j)
    if diff < 15:
        return 0.125
    elif diff < 30:
        return 0.125 * 0.8
    elif diff < 60:
        return 0.125 * 0.6
    elif diff < 90:
        return 0.125 * 0.3
    return 0

def get_sim_language(movie_id_i, movie_id_j):
    language_i = movies[movie_id_i]['language']
    language_j = movies[movie_id_j]['language']
    if language_i == language_j:
        return 0.05
    return 0

def get_sim_origin(movie_id_i, movie_id_j):
    origin_i = movies[movie_id_i]['origin']
    origin_j = movies[movie_id_j]['origin']
    if origin_i == origin_j:
        return 0.025
    return 0

def get_movie_similarities(movie_id_i, movie_id_j):
    sim_director = get_sim_director(movie_id_i, movie_id_i)
    sim_writer = get_sim_writer(movie_id_i, movie_id_j)
    sim_genre = get_sim_genres(movie_id_i, movie_id_j)
    sim_actor = get_sim_actor(movie_id_i, movie_id_j)
    sim_releaseYear = get_sim_releaseYear(movie_id_i, movie_id_j)
    sim_duration = get_sim_duration(movie_id_i, movie_id_j)
    sim_limit = get_sim_limit(movie_id_i, movie_id_j)
    sim_language = get_sim_language(movie_id_i, movie_id_j)
    sim_origin = get_sim_origin(movie_id_i, movie_id_j)

    return sim_director + sim_genre + sim_actor + sim_releaseYear + sim_duration + sim_limit + sim_writer + sim_language + sim_origin

# get_movie_similarities('tt4154756', 'tt4154796')
movie_id = 'tt6025022'
k = 20
list = SortedList()
for id in movies.keys():
    if (id == movie_id):
        continue
    sim = get_movie_similarities(movie_id, id)
    list.add((sim, movies[id]['name']))
    if len(list) > k:
        del list[0]

list
# Out:
# SortedList([(0.8101063829787234, 'Hunter x Hunter'), (0.811734693877551, 'Fullmetal Alchemist'), (0.8142857142857143, 'Naruto: Shippuden'), (0.8154255319148936, 'Demon Slayer: Kimetsu no Yaiba'), (0.8180851063829787, 'Fullmetal Alchemist: Brotherhood'), (0.8194444444444444, 'Attack on Titan'), (0.8221409574468086, 'Over the Garden Wall'), (0.8229166666666667, 'Gravity Falls'), (0.8244927536231884, 'Game of Thrones'), (0.8281250000000001, 'Futurama'), (0.8309659090909092, 'Rick and Morty'), (0.8547872340425532, 'Samurai Champloo'), (0.8591836734693877, 'Arcane'), (0.8904255319148937, 'Regular Show'), (0.8916666666666667, 'The Venture Bros.'), (0.8923913043478261, 'Primal'), (0.8934108527131783, 'Battlestar Galactica'), (0.8972222222222223, 'Young Justice'), (0.9041666666666667, 'Samurai Jack'), (0.9083333333333334, 'Avatar: The Last Airbender')])
